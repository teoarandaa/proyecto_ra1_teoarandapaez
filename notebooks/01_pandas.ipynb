# %% [markdown]
# Importamos las librerias necesarias

# %%
import pandas as pd
print("✅ Todas las librerías están importadas correctamente")
# Out:
# ✅ Todas las librerías están importadas correctamente

# %% [markdown]
# Creamos el Dataframe

# %%
df_housing_barcelona_raw = pd.read_csv("../data/housing-barcelona.csv")
print("✅ El dataframe se ha creado correctamente")
print(df_housing_barcelona_raw.head(3))
# Out:
# ✅ El dataframe se ha creado correctamente
#       price    room   space  \
# 0  269.000€  5 hab.  118 m²
# 1  110.000€  3 hab.   61 m²
# 2   98.000€  3 hab.   58 m²
#
#                                                 name  \
# 0  Piso en Ciutat Meridiana - Torre Baró - Vallbo...
# 1  Piso en Ciutat Meridiana - Torre Baró - Vallbo...
# 2  Piso en calle de les Agudes, Ciutat Meridiana ...
#
#                                            link       city        area  \
# 0  https://www.idealista.com/inmueble/96810038/  barcelona  nou-barris
# 1  https://www.idealista.com/inmueble/97101383/  barcelona  nou-barris
# 2  https://www.idealista.com/inmueble/97293167/  barcelona  nou-barris
#
#                                 subarea  page
# 0  ciutat-meridiana-torre-baro-vallbona     1
# 1  ciutat-meridiana-torre-baro-vallbona     1
# 2  ciutat-meridiana-torre-baro-vallbona     1

# %% [markdown]
# Limpiamos los datos extraidos en nuestro dataframe de datos sucios (Raw)

# %%
def limpiar_datos(df):
